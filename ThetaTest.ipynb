# %%
TDB = """

$ Database file written 2015- 4-16
$ From database: User data 2015.04.13    
 ELEMENT /-   ELECTRON_GAS              0.0000E+00  0.0000E+00  0.0000E+00!
 ELEMENT VA   VACUUM                    0.0000E+00  0.0000E+00  0.0000E+00!
 ELEMENT FE   BCC_A2                    5.5847E+01  4.4890E+03  2.7280E+01!
 ELEMENT MN   CBCC_A12                  5.4938E+01  4.9960E+03  3.2008E+01!
 
 

 FUNCTION TEMP      0.99 +T**(-1); 6000 N !
 FUNCTION RTEMP     0.99 +R#**(-1)*TEMP#; 6000 N !
 FUNCTION ZERO      0.99 +0.0; 6000 N !
 FUNCTION INTR      0.99 +1000; 6000 N !
 FUNCTION INFINITE  0.99 +1000000; 6000 N !
 FUNCTION G2STFCC1  0.99 +9023.52375-2.4952226*T; 6000 N !
 FUNCTION G2STFCC2  0.99 -G2STFCC1#*RTEMP#; 6000 N !
 FUNCTION G2STFCC3  0.99 +1+1*EXP(G2STFCC2#); 6000 N !
 FUNCTION G2STFCC4  0.99 +1*LN(G2STFCC3#); 6000 N !
 FUNCTION G2STFCC   0.99 -R#*T*G2STFCC4#; 6000 N !
 FUNCTION GGBCCL    0.99 -8410.26596-.0032390815*T**2-3.3191338E-14*T**5; 
     6000 N !
 FUNCTION GGBCCH    0.99 -33208.4173+165.40504*T-21.0474823*T*LN(T)
     -2.781828E+18*T**(-5)+4.2811788E+37*T**(-11); 6000 N !
 FUNCTION GEIN309   0.99 +0.0; 6000 N !
 FUNCTION GGFCCL    0.99 -2615.00904-.0027933375*T**2-2.1239087E-14*T**5
     +G2STFCC#; 6000 N !
 FUNCTION GGFCCH    0.99 -32389.5438+168.31394*T-20.9834791*T*LN(T)
     +9.2444598E+18*T**(-5)-1.4750509E+37*T**(-11)+G2STFCC#; 6000 N !
 FUNCTION GHSERFE   0.99 +GGBCCL#+8927.2831-9.7228331*T; 1811 Y
      +GGBCCH#+8927.2831-9.7228331*T; 6000 N !
 FUNCTION GGHCPL    0.99 -3307.07993-.00431797569*T**2-2.1239086E-14*T**5; 
     6000 N !
 FUNCTION GGHCPH    0.99 -24924.6659+161.764208*T-21.0325858*T*LN(T)
     -4.71013343E+18*T**(-5); 6000 N !
 FUNCTION TECBCCMN  0.99 +287.60608; 6000 N !
 FUNCTION TECUBMN   0.99 +247.87895; 6000 N !
 FUNCTION TEFCCMN   0.99 +257.58049; 6000 N !
 FUNCTION TEBCCMN   0.99 +265.03333; 6000 N !
 FUNCTION TELIQMN   0.99 +119.579259; 6000 N !
 FUNCTION TEHCPMN   0.99 +438.579784; 6000 N !
 FUNCTION BETA1     0.99 +1.22; 6000 N !
 FUNCTION BETA2     0.99 +1.62; 6000 N !
 FUNCTION BETA3     0.99 +1.27; 6000 N !
 FUNCTION MNCBCCB   0.99 +1*LN(BETA1#); 6000 N !
 FUNCTION MNFCCB    0.99 +1*LN(BETA2#); 6000 N !
 FUNCTION MNBCCB    0.99 +1*LN(BETA3#); 6000 N !
 FUNCTION GGMNCBCL  0.99 -8621.707-.0054695069*T**2+3.6645644E-08*T**3
     -2.588845E-14*T**5; 6000 N !
 FUNCTION GGMNCBCH  0.99 -25954.328+130.73341*T+20.178863*T
     -20.178863*T*LN(T)-7.4173873E+17*T**(-5)+3.5722E+36*T**(-11); 6000 N !
 FUNCTION GGMNCUBL  0.99 -6181.4708-.0057218755*T**2+8.9632678E-12*T**3
     -1.9360399E-14*T**5; 6000 N !
 FUNCTION GGMNCUBH  0.99 -24465.161+136.70198*T+21.095719*T
     -21.095719*T*LN(T)-3.967E+17*T**(-5)+2.9953E+36*T**(-11); 6000 N !
 FUNCTION GGMNFCCL  0.99 -5356.328-.0044627084*T**2-3.7906096E-10*T**4
     +8.1018765E-14*T**5; 6000 N !
 FUNCTION GGMNFCCH  0.99 -22440.434+135.25456*T+20.797951*T
     -20.797951*T*LN(T)-1.8964E+18*T**(-5)+5.208E+36*T**(-11); 6000 N !
 FUNCTION GGMNBCCL  0.99 -4692.6774-.006846492*T**2-3.2311349E-15*T**5; 
     6000 N !
 FUNCTION GGMNBCCH  0.99 -18620.432+127.31728*T+20.301009*T
     -20.301009*T*LN(T)-2.2035E+18*T**(-5)+5.1886E+36*T**(-11); 6000 N !
 FUNCTION GGMNHCPL  0.99 -9755.88935-.00699764166*T**2+4.12888434E-15*T**5;
      6000 N !
 FUNCTION GGMNHCPH  0.99 -25379.581+133.19315*T+21.0957581*T
     -21.0957581*T*LN(T)-1.1043E+18*T**(-5)+3.3993E+36*T**(-11); 6000 N !
 FUNCTION UN_ASS    0.99 +0.0; 300 N !
 
 TYPE_DEFINITION % SEQ *!
 DEFINE_SYSTEM_DEFAULT ELEMENT 2 !
 DEFAULT_COMMAND DEF_SYS_ELEMENT VA /- !


 TYPE_DEFINITION & GES A_P_D BCC_A2 MAGNETIC   0.0    0.37 !
 PHASE BCC_A2  %&  2 1   3 !
    CONSTITUENT BCC_A2  :FE,MN : VA :  !

   PARAMETER G(BCC_A2,FE:VA;0)            0.99 +GGBCCL#+8927.2831-9.7228331*T;
   1811 Y
   +GGBCCH#+8927.2831-9.7228331*T; 6000 N REF0 !
   PARAMETER THETA(BCC_A2,FE:VA;0)        0.99 +1*309; 6000 N REF0 !
   PARAMETER G(BCC_A2,MN:VA;0)              0.99 +GGMNBCCL#+4245.28448*MNBCCB#
  -8.31451*MNBCCB#*T; 1519 Y
   +GGMNBCCH#+4245.28448*MNBCCB#-8.31451*MNBCCB#*T; 6000 N REF0 !
   $PARAMETER THETA(BCC_A2,MN:VA;0)        0.99 +1*265; 6000 N 
  $ REF0 !
   PARAMETER G(BCC_A2,FE,MN:VA;0)         0.99 -1.4302789E+03+2.4542744E+00*T; 6000 N REF0 !
   PARAMETER G(BCC_A2,FE,MN:VA;1)         0.99 6.6801606E+02+4.2545472E-02*T; 6000 N REF0 !

"""

# %%
from pycalphad import Database, Model, equilibrium, calculate
import pycalphad.variables as v
from tinydb import where
import sympy
from sympy import S, log, exp

import pycalphad.io.tdb_keywords
pycalphad.io.tdb_keywords.TDB_PARAM_TYPES.extend(['THETA', 'THETAX', 'THETAY','THETAZ'])

class EinsteinModel(Model):     
    def einstein_energy(self, dbe):
        phase = dbe.phases[self.phase_name]
        param_search = dbe.search
        theta_param_query = (
            (where('phase_name') == phase.name) & \
            (where('parameter_type') == 'THETA') & \
            (where('constituent_array').test(self._array_validity))
        )
        thetax_param_query = (
            (where('phase_name') == phase.name) & \
            (where('parameter_type') == 'THETAX') & \
            (where('constituent_array').test(self._array_validity))
        )
        thetay_param_query = (
            (where('phase_name') == phase.name) & \
            (where('parameter_type') == 'THETAY') & \
            (where('constituent_array').test(self._array_validity))
        )
        thetaz_param_query = (
            (where('phase_name') == phase.name) & \
            (where('parameter_type') == 'THETAZ') & \
            (where('constituent_array').test(self._array_validity))
        )
        theta = self.redlich_kister_sum(phase, param_search, theta_param_query)
        thetax = self.redlich_kister_sum(phase, param_search, thetax_param_query)
        thetay = self.redlich_kister_sum(phase, param_search, thetay_param_query)
        thetaz = self.redlich_kister_sum(phase, param_search, thetaz_param_query)
        self.theta = self.symbol_replace(theta, dbe.symbols)
        if theta != 0:
            result = 1.5*v.R*theta + 3*v.R*v.T*sympy.log(1-sympy.exp(-theta/v.T))
        else:
            result = 0
        if thetax != 0:
            resultx = 1.5*v.R*thetax + 3*v.R*v.T*sympy.log(1-sympy.exp(-thetax/v.T))
        else:
            resultx = 0
        if thetay != 0:
            resulty = 1.5*v.R*thetay + 3*v.R*v.T*sympy.log(1-sympy.exp(-thetay/v.T))
        else:
            resulty = 0
        if thetaz != 0:
            resultz = 1.5*v.R*thetaz + 3*v.R*v.T*sympy.log(1-sympy.exp(-thetaz/v.T))
        else:
            resultz = 0
        return (result + (resultx+resulty+resultz)/3) / self._site_ratio_normalization(phase)

    einstein_cpm = property(lambda self: -v.T*self.models['ein'].diff(v.T, v.T))
    einstein_gm = property(lambda self: self.models['ein'])

# %%
from pycalphad import calculate
dbf = Database(TDB)
res = calculate(dbf, ['MN', 'FE', 'VA'], 'BCC_A2', T=310, P=101325, output='theta', model=EinsteinModel)

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib 
import numpy as np
matplotlib.style.use('seaborn-poster')

fig = plt.figure(figsize=(16,9))
ax = fig.gca()

comps_to_sort = res['X'].sel(component='MN').values.flatten()
sort_indices = np.argsort(comps_to_sort)

ax.plot(comps_to_sort[sort_indices], res['theta'].values.flatten()[sort_indices])

ax.set_xlabel('X(MN)')
ax.set_ylabel('Einstein Temperature')

# %%
from pycalphad import calculate
dbf = Database(TDB)
res = calculate(dbf, ['MN', 'FE', 'VA'], 'BCC_A2', T=310, P=101325, output='einstein_cpm', model=EinsteinModel)

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib 
import numpy as np
matplotlib.style.use('seaborn-poster')

fig = plt.figure(figsize=(16,9))
ax = fig.gca()

comps_to_sort = res['X'].sel(component='MN').values.flatten()
sort_indices = np.argsort(comps_to_sort)

ax.plot(comps_to_sort[sort_indices], res['einstein_cpm'].values.flatten()[sort_indices])

ax.set_xlabel('X(MN)')
ax.set_ylabel('Einstein Isobaric Heat Capacity (J/K-mol-atom)')

# %%
from pycalphad import calculate
dbf = Database(TDB)
res = calculate(dbf, ['MN', 'FE', 'VA'], 'BCC_A2', T=310, P=101325, output='einstein_gm', model=EinsteinModel)

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib 
import numpy as np
matplotlib.style.use('seaborn-poster')

fig = plt.figure(figsize=(16,9))
ax = fig.gca()

comps_to_sort = res['X'].sel(component='MN').values.flatten()
sort_indices = np.argsort(comps_to_sort)

ax.plot(comps_to_sort[sort_indices], res['einstein_gm'].values.flatten()[sort_indices])

ax.set_xlabel('X(MN)')
ax.set_ylabel('Einstein Gibbs Energy (J/mol-atom)')

# %%
from pycalphad import binplot
dbf = Database(TDB)
res = binplot(dbf, ['MN', 'FE', 'VA'], dbf.phases.keys(), {v.T: (300,2000,100), v.P: 101325, v.X('MN'): (0,1,0.1)},
              eq_kwargs={'model': EinsteinModel})
